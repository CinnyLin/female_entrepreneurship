# %% [markdown]
# [stackoverflow](https://stackoverflow.com/questions/21494141/how-do-i-do-a-f-test-in-python) on python test

# %%
# import dependencies 
import pandas as pd
# from scipy.stats import ttest_ind
# from scipy.stats import bartlett
from scipy.stats import levene
from collections import Counter

# %% [markdown]
# ## Tests
#
# 1. `ttest_ind`
# Calculate the T-test for the means of two independent samples of scores.
#
# This is a two-sided test for the null hypothesis that 2 independent samples have identical average (expected) values. This test assumes that the populations have identical variances by default.
#
# 2. `bartlett`
# Perform Bartlett’s test for equal variances.
#
# Bartlett’s test tests the null hypothesis that all input samples are from populations with equal variances. For samples from significantly non-normal populations, Levene’s test levene is more robust.
#
# 3. **`levene`**
# Perform Levene test for equal variances.
#
# The Levene test tests the null hypothesis that all input samples are from populations with equal variances. Levene’s test is an alternative to Bartlett’s test bartlett in the case where there are significant deviations from normality.

# %%
# manual input based on headquarters region filter
regions = ['US', 'EU', 'Europe', 'China']

# %% [markdown]
# ### Run Significance Tests + Export Results
# compare gender difference within region

# %%
def test_diff(n):
    '''compare within region'''

    df_metrics = pd.DataFrame()
    df_metrics['region'] = regions

    by_industry_group = ['industry_groups', 'industries']

    for big in by_industry_group:

            # initiate containers
            female_co_std_data = []
            not_female_co_std_data = []

            # significance test
            levene_stat_data = []
            levene_p_data = []

            for region in regions:

                df = pd.read_csv(f'../data/crunchbase-aggregated/{region}-{n}-{big}.csv')

                # female
                female_co_std = df['#female_co'].std()
                female_co_std_data.append(female_co_std)

                # not female
                not_female_co_std = df['#not_female_co'].std()
                not_female_co_std_data.append(not_female_co_std)

                # significance test
                stat3, p3 = levene(df['#female_co'].dropna(), df['#not_female_co'].dropna(), center='mean')
                levene_stat_data.append(stat3)
                levene_p_data.append(p3)


            # add data to df
            if (big=='industries'):
                df_metrics[f'#female_co_std_{n}'] = female_co_std_data
                df_metrics[f'#not_female_co_std_{n}'] = not_female_co_std_data
                df_metrics[f'levene_stat_{n}'] = levene_stat_data
                df_metrics[f'levene_p_{n}'] = levene_p_data

            elif (big=='industry_groups'):
                df_metrics[f'#female_co_std_group_{n}'] = female_co_std_data
                df_metrics[f'#not_female_co_std_group_{n}'] = not_female_co_std_data
                df_metrics[f'levene_stat_group_{n}'] = levene_stat_data
                df_metrics[f'levene_p_group_{n}'] = levene_p_data
    
    return df_metrics

# %%
def present_test_diff(df_metrics, axis=0):
    p_cols  = [col for col in df_metrics.columns if '_p' in col]
    df_p = df_metrics[['region']+p_cols]
    return df_p.style.background_gradient(cmap='Blues', axis=axis)

# %%
present_test_diff(test_diff(98))
# Out:
# <style  type="text/css" >
# #T_a6b37_row0_col1,#T_a6b37_row1_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_a6b37_row0_col2{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_a6b37_row1_col1{
#             background-color:  #083a7a;
#             color:  #f1f1f1;
#         }#T_a6b37_row2_col1{
#             background-color:  #4a98c9;
#             color:  #000000;
#         }#T_a6b37_row2_col2{
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }#T_a6b37_row3_col1,#T_a6b37_row3_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_a6b37_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >region</th>        <th class="col_heading level0 col1" >levene_p_group_98</th>        <th class="col_heading level0 col2" >levene_p_98</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a6b37_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a6b37_row0_col0" class="data row0 col0" >US</td>
#                         <td id="T_a6b37_row0_col1" class="data row0 col1" >0.649598</td>
#                         <td id="T_a6b37_row0_col2" class="data row0 col2" >0.555815</td>
#             </tr>
#             <tr>
#                         <th id="T_a6b37_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a6b37_row1_col0" class="data row1 col0" >EU</td>
#                         <td id="T_a6b37_row1_col1" class="data row1 col1" >0.625603</td>
#                         <td id="T_a6b37_row1_col2" class="data row1 col2" >0.856606</td>
#             </tr>
#             <tr>
#                         <th id="T_a6b37_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a6b37_row2_col0" class="data row2 col0" >Europe</td>
#                         <td id="T_a6b37_row2_col1" class="data row2 col1" >0.417509</td>
#                         <td id="T_a6b37_row2_col2" class="data row2 col2" >0.083795</td>
#             </tr>
#             <tr>
#                         <th id="T_a6b37_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a6b37_row3_col0" class="data row3 col0" >China</td>
#                         <td id="T_a6b37_row3_col1" class="data row3 col1" >0.067952</td>
#                         <td id="T_a6b37_row3_col2" class="data row3 col2" >0.014168</td>
#             </tr>
#     </tbody></table>

# %%
present_test_diff(test_diff(32))
# Out:
# <style  type="text/css" >
# #T_c4890_row0_col1,#T_c4890_row0_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_c4890_row1_col1{
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }#T_c4890_row1_col2{
#             background-color:  #206fb4;
#             color:  #f1f1f1;
#         }#T_c4890_row2_col1{
#             background-color:  #08326e;
#             color:  #f1f1f1;
#         }#T_c4890_row2_col2{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_c4890_row3_col1,#T_c4890_row3_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_c4890_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >region</th>        <th class="col_heading level0 col1" >levene_p_group_32</th>        <th class="col_heading level0 col2" >levene_p_32</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c4890_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c4890_row0_col0" class="data row0 col0" >US</td>
#                         <td id="T_c4890_row0_col1" class="data row0 col1" >0.848429</td>
#                         <td id="T_c4890_row0_col2" class="data row0 col2" >0.945040</td>
#             </tr>
#             <tr>
#                         <th id="T_c4890_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c4890_row1_col0" class="data row1 col0" >EU</td>
#                         <td id="T_c4890_row1_col1" class="data row1 col1" >0.638911</td>
#                         <td id="T_c4890_row1_col2" class="data row1 col2" >0.741564</td>
#             </tr>
#             <tr>
#                         <th id="T_c4890_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c4890_row2_col0" class="data row2 col0" >Europe</td>
#                         <td id="T_c4890_row2_col1" class="data row2 col1" >0.840758</td>
#                         <td id="T_c4890_row2_col2" class="data row2 col2" >0.214286</td>
#             </tr>
#             <tr>
#                         <th id="T_c4890_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c4890_row3_col0" class="data row3 col0" >China</td>
#                         <td id="T_c4890_row3_col1" class="data row3 col1" >0.023067</td>
#                         <td id="T_c4890_row3_col2" class="data row3 col2" >0.108388</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Run Significance Tests + Export Results
# compare industry difference across regions

# %%
def test_diff_region(n=''):
    '''compare between regions'''

    df_metrics = pd.DataFrame()
    regions = ['US', 'EU', 'Europe', 'China']

    by_industry_group = ['industry_groups', 'industries']

    for big in by_industry_group:
        
            region_pair_data = []

            # significance test
            levene_stat_female_data = []
            levene_p_female_data = []
            levene_stat_all_data = []
            levene_p_all_data = []

            for region1 in regions:
                for region2 in regions:
                    
                    if region1==region2:
                        pass
                    
                    else:
                        region_pair_data.append([region1, region2])

                        if isinstance(n, int):
                            df1 = pd.read_csv(f'../data/crunchbase-aggregated/{region1}-{n}-{big}.csv')
                            df2 = pd.read_csv(f'../data/crunchbase-aggregated/{region2}-{n}-{big}.csv')

                        else: #full data
                            df1 = pd.read_csv(f'../data/crunchbase-aggregated/{region1}-{big}_equal.csv')
                            df2 = pd.read_csv(f'../data/crunchbase-aggregated/{region2}-{big}_equal.csv')

                        # combined
                        df1['#all_co'] = df1['#female_co'] + df1['#not_female_co']
                        df2['#all_co'] = df2['#female_co'] + df2['#not_female_co']

                        # significance test
                        stat1, p1 = levene(df1['#female_co'].dropna(), df2['#female_co'].dropna())
                        levene_stat_female_data.append(stat1)
                        levene_p_female_data.append(p1)

                        stat2, p2 = levene(df1['#all_co'].dropna(), df2['#all_co'].dropna())
                        levene_stat_all_data.append(stat2)
                        levene_p_all_data.append(p2)


            # add data to df
            if (big=='industries'):
                df_metrics[f'levene_stat_f{n}'] = levene_stat_female_data
                df_metrics[f'levene_p_f{n}'] = levene_p_female_data
                df_metrics[f'levene_stat_all{n}'] = levene_stat_all_data
                df_metrics[f'levene_p_all{n}'] = levene_p_all_data

            elif (big=='industry_groups'):
                df_metrics[f'levene_stat_group_f{n}'] = levene_stat_female_data
                df_metrics[f'levene_p_group_f{n}'] = levene_p_female_data
                df_metrics[f'levene_stat_group_all{n}'] = levene_stat_all_data
                df_metrics[f'levene_p_group_all{n}'] = levene_p_all_data

    df_metrics['region'] = region_pair_data
    return df_metrics

# %%
present_test_diff(test_diff_region(98))
# Out:
# <style  type="text/css" >
# #T_c2063_row0_col1,#T_c2063_row3_col1{
#             background-color:  #71b1d7;
#             color:  #000000;
#         }#T_c2063_row0_col2,#T_c2063_row3_col2{
#             background-color:  #3787c0;
#             color:  #000000;
#         }#T_c2063_row0_col3,#T_c2063_row3_col3{
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }#T_c2063_row0_col4,#T_c2063_row3_col4{
#             background-color:  #4191c6;
#             color:  #000000;
#         }#T_c2063_row1_col1,#T_c2063_row1_col3,#T_c2063_row2_col4,#T_c2063_row6_col1,#T_c2063_row6_col3,#T_c2063_row8_col2,#T_c2063_row9_col4,#T_c2063_row11_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_c2063_row1_col2,#T_c2063_row2_col1,#T_c2063_row4_col4,#T_c2063_row5_col3,#T_c2063_row6_col2,#T_c2063_row7_col4,#T_c2063_row9_col1,#T_c2063_row10_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_c2063_row1_col4,#T_c2063_row4_col2,#T_c2063_row6_col4,#T_c2063_row7_col2{
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }#T_c2063_row2_col2,#T_c2063_row9_col2{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_c2063_row2_col3,#T_c2063_row9_col3{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_c2063_row4_col1,#T_c2063_row7_col1{
#             background-color:  #3383be;
#             color:  #000000;
#         }#T_c2063_row4_col3,#T_c2063_row7_col3{
#             background-color:  #7cb7da;
#             color:  #000000;
#         }#T_c2063_row5_col1,#T_c2063_row10_col1{
#             background-color:  #4493c7;
#             color:  #000000;
#         }#T_c2063_row5_col2,#T_c2063_row10_col2{
#             background-color:  #8abfdd;
#             color:  #000000;
#         }#T_c2063_row5_col4,#T_c2063_row8_col4,#T_c2063_row10_col4,#T_c2063_row11_col4{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_c2063_row8_col1,#T_c2063_row11_col1{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_c2063_row8_col3,#T_c2063_row11_col3{
#             background-color:  #97c6df;
#             color:  #000000;
#         }</style><table id="T_c2063_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >region</th>        <th class="col_heading level0 col1" >levene_p_group_f98</th>        <th class="col_heading level0 col2" >levene_p_group_all98</th>        <th class="col_heading level0 col3" >levene_p_f98</th>        <th class="col_heading level0 col4" >levene_p_all98</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2063_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c2063_row0_col0" class="data row0 col0" >['US', 'EU']</td>
#                         <td id="T_c2063_row0_col1" class="data row0 col1" >0.735366</td>
#                         <td id="T_c2063_row0_col2" class="data row0 col2" >0.877441</td>
#                         <td id="T_c2063_row0_col3" class="data row0 col3" >0.631559</td>
#                         <td id="T_c2063_row0_col4" class="data row0 col4" >0.817958</td>
#             </tr>
#             <tr>
#                         <th id="T_c2063_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c2063_row1_col0" class="data row1 col0" >['US', 'Europe']</td>
#                         <td id="T_c2063_row1_col1" class="data row1 col1" >0.543414</td>
#                         <td id="T_c2063_row1_col2" class="data row1 col2" >0.992644</td>
#                         <td id="T_c2063_row1_col3" class="data row1 col3" >0.357452</td>
#                         <td id="T_c2063_row1_col4" class="data row1 col4" >0.821754</td>
#             </tr>
#             <tr>
#                         <th id="T_c2063_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c2063_row2_col0" class="data row2 col0" >['US', 'China']</td>
#                         <td id="T_c2063_row2_col1" class="data row2 col1" >0.938270</td>
#                         <td id="T_c2063_row2_col2" class="data row2 col2" >0.668532</td>
#                         <td id="T_c2063_row2_col3" class="data row2 col3" >0.697657</td>
#                         <td id="T_c2063_row2_col4" class="data row2 col4" >0.520438</td>
#             </tr>
#             <tr>
#                         <th id="T_c2063_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c2063_row3_col0" class="data row3 col0" >['EU', 'US']</td>
#                         <td id="T_c2063_row3_col1" class="data row3 col1" >0.735366</td>
#                         <td id="T_c2063_row3_col2" class="data row3 col2" >0.877441</td>
#                         <td id="T_c2063_row3_col3" class="data row3 col3" >0.631559</td>
#                         <td id="T_c2063_row3_col4" class="data row3 col4" >0.817958</td>
#             </tr>
#             <tr>
#                         <th id="T_c2063_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c2063_row4_col0" class="data row4 col0" >['EU', 'Europe']</td>
#                         <td id="T_c2063_row4_col1" class="data row4 col1" >0.812232</td>
#                         <td id="T_c2063_row4_col2" class="data row4 col2" >0.866564</td>
#                         <td id="T_c2063_row4_col3" class="data row4 col3" >0.628524</td>
#                         <td id="T_c2063_row4_col4" class="data row4 col4" >0.995705</td>
#             </tr>
#             <tr>
#                         <th id="T_c2063_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c2063_row5_col0" class="data row5 col0" >['EU', 'China']</td>
#                         <td id="T_c2063_row5_col1" class="data row5 col1" >0.787677</td>
#                         <td id="T_c2063_row5_col2" class="data row5 col2" >0.793488</td>
#                         <td id="T_c2063_row5_col3" class="data row5 col3" >0.949908</td>
#                         <td id="T_c2063_row5_col4" class="data row5 col4" >0.638621</td>
#             </tr>
#             <tr>
#                         <th id="T_c2063_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c2063_row6_col0" class="data row6 col0" >['Europe', 'US']</td>
#                         <td id="T_c2063_row6_col1" class="data row6 col1" >0.543414</td>
#                         <td id="T_c2063_row6_col2" class="data row6 col2" >0.992644</td>
#                         <td id="T_c2063_row6_col3" class="data row6 col3" >0.357452</td>
#                         <td id="T_c2063_row6_col4" class="data row6 col4" >0.821754</td>
#             </tr>
#             <tr>
#                         <th id="T_c2063_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c2063_row7_col0" class="data row7 col0" >['Europe', 'EU']</td>
#                         <td id="T_c2063_row7_col1" class="data row7 col1" >0.812232</td>
#                         <td id="T_c2063_row7_col2" class="data row7 col2" >0.866564</td>
#                         <td id="T_c2063_row7_col3" class="data row7 col3" >0.628524</td>
#                         <td id="T_c2063_row7_col4" class="data row7 col4" >0.995705</td>
#             </tr>
#             <tr>
#                         <th id="T_c2063_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c2063_row8_col0" class="data row8 col0" >['Europe', 'China']</td>
#                         <td id="T_c2063_row8_col1" class="data row8 col1" >0.583470</td>
#                         <td id="T_c2063_row8_col2" class="data row8 col2" >0.646357</td>
#                         <td id="T_c2063_row8_col3" class="data row8 col3" >0.590276</td>
#                         <td id="T_c2063_row8_col4" class="data row8 col4" >0.637670</td>
#             </tr>
#             <tr>
#                         <th id="T_c2063_level0_row9" class="row_heading level0 row9" >9</th>
#                         <

# %%
present_test_diff(test_diff_region(32))
# Out:
# <style  type="text/css" >
# #T_fcdc6_row0_col1,#T_fcdc6_row3_col1{
#             background-color:  #dfecf7;
#             color:  #000000;
#         }#T_fcdc6_row0_col2,#T_fcdc6_row3_col2{
#             background-color:  #a5cde3;
#             color:  #000000;
#         }#T_fcdc6_row0_col3,#T_fcdc6_row3_col3{
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }#T_fcdc6_row0_col4,#T_fcdc6_row2_col1,#T_fcdc6_row2_col3,#T_fcdc6_row3_col4,#T_fcdc6_row4_col1,#T_fcdc6_row4_col2,#T_fcdc6_row7_col1,#T_fcdc6_row7_col2,#T_fcdc6_row9_col1,#T_fcdc6_row9_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_fcdc6_row1_col1,#T_fcdc6_row2_col2,#T_fcdc6_row4_col3,#T_fcdc6_row4_col4,#T_fcdc6_row6_col1,#T_fcdc6_row7_col3,#T_fcdc6_row7_col4,#T_fcdc6_row9_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_fcdc6_row1_col2,#T_fcdc6_row2_col4,#T_fcdc6_row5_col2,#T_fcdc6_row6_col2,#T_fcdc6_row9_col4,#T_fcdc6_row10_col2{
#             background-color:  #a4cce3;
#             color:  #000000;
#         }#T_fcdc6_row1_col3,#T_fcdc6_row6_col3{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_fcdc6_row1_col4,#T_fcdc6_row6_col4{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_fcdc6_row5_col1,#T_fcdc6_row10_col1{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_fcdc6_row5_col3,#T_fcdc6_row10_col3{
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }#T_fcdc6_row5_col4,#T_fcdc6_row10_col4{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_fcdc6_row8_col1,#T_fcdc6_row11_col1{
#             background-color:  #d2e3f3;
#             color:  #000000;
#         }#T_fcdc6_row8_col2,#T_fcdc6_row11_col2{
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }#T_fcdc6_row8_col3,#T_fcdc6_row11_col3{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_fcdc6_row8_col4,#T_fcdc6_row11_col4{
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }</style><table id="T_fcdc6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >region</th>        <th class="col_heading level0 col1" >levene_p_group_f32</th>        <th class="col_heading level0 col2" >levene_p_group_all32</th>        <th class="col_heading level0 col3" >levene_p_f32</th>        <th class="col_heading level0 col4" >levene_p_all32</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fcdc6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fcdc6_row0_col0" class="data row0 col0" >['US', 'EU']</td>
#                         <td id="T_fcdc6_row0_col1" class="data row0 col1" >0.499817</td>
#                         <td id="T_fcdc6_row0_col2" class="data row0 col2" >0.448983</td>
#                         <td id="T_fcdc6_row0_col3" class="data row0 col3" >0.851834</td>
#                         <td id="T_fcdc6_row0_col4" class="data row0 col4" >0.931535</td>
#             </tr>
#             <tr>
#                         <th id="T_fcdc6_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fcdc6_row1_col0" class="data row1 col0" >['US', 'Europe']</td>
#                         <td id="T_fcdc6_row1_col1" class="data row1 col1" >0.444848</td>
#                         <td id="T_fcdc6_row1_col2" class="data row1 col2" >0.451643</td>
#                         <td id="T_fcdc6_row1_col3" class="data row1 col3" >0.109068</td>
#                         <td id="T_fcdc6_row1_col4" class="data row1 col4" >0.214902</td>
#             </tr>
#             <tr>
#                         <th id="T_fcdc6_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fcdc6_row2_col0" class="data row2 col0" >['US', 'China']</td>
#                         <td id="T_fcdc6_row2_col1" class="data row2 col1" >0.905310</td>
#                         <td id="T_fcdc6_row2_col2" class="data row2 col2" >0.163014</td>
#                         <td id="T_fcdc6_row2_col3" class="data row2 col3" >0.938730</td>
#                         <td id="T_fcdc6_row2_col4" class="data row2 col4" >0.434139</td>
#             </tr>
#             <tr>
#                         <th id="T_fcdc6_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fcdc6_row3_col0" class="data row3 col0" >['EU', 'US']</td>
#                         <td id="T_fcdc6_row3_col1" class="data row3 col1" >0.499817</td>
#                         <td id="T_fcdc6_row3_col2" class="data row3 col2" >0.448983</td>
#                         <td id="T_fcdc6_row3_col3" class="data row3 col3" >0.851834</td>
#                         <td id="T_fcdc6_row3_col4" class="data row3 col4" >0.931535</td>
#             </tr>
#             <tr>
#                         <th id="T_fcdc6_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_fcdc6_row4_col0" class="data row4 col0" >['EU', 'Europe']</td>
#                         <td id="T_fcdc6_row4_col1" class="data row4 col1" >0.906503</td>
#                         <td id="T_fcdc6_row4_col2" class="data row4 col2" >0.974327</td>
#                         <td id="T_fcdc6_row4_col3" class="data row4 col3" >0.104703</td>
#                         <td id="T_fcdc6_row4_col4" class="data row4 col4" >0.156634</td>
#             </tr>
#             <tr>
#                         <th id="T_fcdc6_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_fcdc6_row5_col0" class="data row5 col0" >['EU', 'China']</td>
#                         <td id="T_fcdc6_row5_col1" class="data row5 col1" >0.593851</td>
#                         <td id="T_fcdc6_row5_col2" class="data row5 col2" >0.454094</td>
#                         <td id="T_fcdc6_row5_col3" class="data row5 col3" >0.809041</td>
#                         <td id="T_fcdc6_row5_col4" class="data row5 col4" >0.311157</td>
#             </tr>
#             <tr>
#                         <th id="T_fcdc6_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_fcdc6_row6_col0" class="data row6 col0" >['Europe', 'US']</td>
#                         <td id="T_fcdc6_row6_col1" class="data row6 col1" >0.444848</td>
#                         <td id="T_fcdc6_row6_col2" class="data row6 col2" >0.451643</td>
#                         <td id="T_fcdc6_row6_col3" class="data row6 col3" >0.109068</td>
#                         <td id="T_fcdc6_row6_col4" class="data row6 col4" >0.214902</td>
#             </tr>
#             <tr>
#                         <th id="T_fcdc6_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_fcdc6_row7_col0" class="data row7 col0" >['Europe', 'EU']</td>
#                         <td id="T_fcdc6_row7_col1" class="data row7 col1" >0.906503</td>
#                         <td id="T_fcdc6_row7_col2" class="data row7 col2" >0.974327</td>
#                         <td id="T_fcdc6_row7_col3" class="data row7 col3" >0.104703</td>
#                         <td id="T_fcdc6_row7_col4" class="data row7 col4" >0.156634</td>
#             </tr>
#             <tr>
#                         <th id="T_fcdc6_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_fcdc6_row8_col0" class="data row8 col0" >['Europe', 'China']</td>
#                         <td id="T_fcdc6_row8_col1" class="data row8 col1" >0.532174</td>
#                         <td id="T_fcdc6_row8_col2" class="data row8 col2" >0.500734</td>
#                         <td id="T_fcdc6_row8_col3" class="data row8 col3" >0.137592</td>
#                         <td id="T_fcdc6_row8_col4" class="data row8 col4" >0.656724</td>
#             </tr>
#             <tr>
#                         <th id="T_fcdc6_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_fcdc6_row9_col0" class="data row9 col0" >['China', 'US']</td>

# %%
present_test_diff(test_diff_region())
# Out:
# <style  type="text/css" >
# #T_134bd_row0_col1,#T_134bd_row3_col1{
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }#T_134bd_row0_col2,#T_134bd_row3_col2{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_134bd_row0_col3,#T_134bd_row3_col3{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_134bd_row0_col4,#T_134bd_row3_col4{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_134bd_row1_col1,#T_134bd_row6_col1{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_134bd_row1_col2,#T_134bd_row6_col2{
#             background-color:  #74b3d8;
#             color:  #000000;
#         }#T_134bd_row1_col3,#T_134bd_row6_col3{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_134bd_row1_col4,#T_134bd_row6_col4{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_134bd_row2_col1,#T_134bd_row2_col2,#T_134bd_row2_col3,#T_134bd_row2_col4,#T_134bd_row9_col1,#T_134bd_row9_col2,#T_134bd_row9_col3,#T_134bd_row9_col4{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_134bd_row4_col1,#T_134bd_row4_col2,#T_134bd_row4_col3,#T_134bd_row4_col4,#T_134bd_row7_col1,#T_134bd_row7_col2,#T_134bd_row7_col3,#T_134bd_row7_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_134bd_row5_col1,#T_134bd_row10_col1{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_134bd_row5_col2,#T_134bd_row10_col2{
#             background-color:  #caddf0;
#             color:  #000000;
#         }#T_134bd_row5_col3,#T_134bd_row10_col3{
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }#T_134bd_row5_col4,#T_134bd_row10_col4{
#             background-color:  #e4eff9;
#             color:  #000000;
#         }#T_134bd_row8_col1,#T_134bd_row11_col1{
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }#T_134bd_row8_col2,#T_134bd_row11_col2{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_134bd_row8_col3,#T_134bd_row11_col3{
#             background-color:  #cbdef1;
#             color:  #000000;
#         }#T_134bd_row8_col4,#T_134bd_row11_col4{
#             background-color:  #e2edf8;
#             color:  #000000;
#         }</style><table id="T_134bd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >region</th>        <th class="col_heading level0 col1" >levene_p_group_f</th>        <th class="col_heading level0 col2" >levene_p_group_all</th>        <th class="col_heading level0 col3" >levene_p_f</th>        <th class="col_heading level0 col4" >levene_p_all</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_134bd_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_134bd_row0_col0" class="data row0 col0" >['US', 'EU']</td>
#                         <td id="T_134bd_row0_col1" class="data row0 col1" >0.139609</td>
#                         <td id="T_134bd_row0_col2" class="data row0 col2" >0.198675</td>
#                         <td id="T_134bd_row0_col3" class="data row0 col3" >0.096929</td>
#                         <td id="T_134bd_row0_col4" class="data row0 col4" >0.146754</td>
#             </tr>
#             <tr>
#                         <th id="T_134bd_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_134bd_row1_col0" class="data row1 col0" >['US', 'Europe']</td>
#                         <td id="T_134bd_row1_col1" class="data row1 col1" >0.172740</td>
#                         <td id="T_134bd_row1_col2" class="data row1 col2" >0.359467</td>
#                         <td id="T_134bd_row1_col3" class="data row1 col3" >0.064217</td>
#                         <td id="T_134bd_row1_col4" class="data row1 col4" >0.188595</td>
#             </tr>
#             <tr>
#                         <th id="T_134bd_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_134bd_row2_col0" class="data row2 col0" >['US', 'China']</td>
#                         <td id="T_134bd_row2_col1" class="data row2 col1" >0.022264</td>
#                         <td id="T_134bd_row2_col2" class="data row2 col2" >0.019831</td>
#                         <td id="T_134bd_row2_col3" class="data row2 col3" >0.011741</td>
#                         <td id="T_134bd_row2_col4" class="data row2 col4" >0.013730</td>
#             </tr>
#             <tr>
#                         <th id="T_134bd_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_134bd_row3_col0" class="data row3 col0" >['EU', 'US']</td>
#                         <td id="T_134bd_row3_col1" class="data row3 col1" >0.139609</td>
#                         <td id="T_134bd_row3_col2" class="data row3 col2" >0.198675</td>
#                         <td id="T_134bd_row3_col3" class="data row3 col3" >0.096929</td>
#                         <td id="T_134bd_row3_col4" class="data row3 col4" >0.146754</td>
#             </tr>
#             <tr>
#                         <th id="T_134bd_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_134bd_row4_col0" class="data row4 col0" >['EU', 'Europe']</td>
#                         <td id="T_134bd_row4_col1" class="data row4 col1" >0.910166</td>
#                         <td id="T_134bd_row4_col2" class="data row4 col2" >0.727516</td>
#                         <td id="T_134bd_row4_col3" class="data row4 col3" >0.878763</td>
#                         <td id="T_134bd_row4_col4" class="data row4 col4" >0.883936</td>
#             </tr>
#             <tr>
#                         <th id="T_134bd_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_134bd_row5_col0" class="data row5 col0" >['EU', 'China']</td>
#                         <td id="T_134bd_row5_col1" class="data row5 col1" >0.328160</td>
#                         <td id="T_134bd_row5_col2" class="data row5 col2" >0.183714</td>
#                         <td id="T_134bd_row5_col3" class="data row5 col3" >0.166430</td>
#                         <td id="T_134bd_row5_col4" class="data row5 col4" >0.098380</td>
#             </tr>
#             <tr>
#                         <th id="T_134bd_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_134bd_row6_col0" class="data row6 col0" >['Europe', 'US']</td>
#                         <td id="T_134bd_row6_col1" class="data row6 col1" >0.172740</td>
#                         <td id="T_134bd_row6_col2" class="data row6 col2" >0.359467</td>
#                         <td id="T_134bd_row6_col3" class="data row6 col3" >0.064217</td>
#                         <td id="T_134bd_row6_col4" class="data row6 col4" >0.188595</td>
#             </tr>
#             <tr>
#                         <th id="T_134bd_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_134bd_row7_col0" class="data row7 col0" >['Europe', 'EU']</td>
#                         <td id="T_134bd_row7_col1" class="data row7 col1" >0.910166</td>
#                         <td id="T_134bd_row7_col2" class="data row7 col2" >0.727516</td>
#                         <td id="T_134bd_row7_col3" class="data row7 col3" >0.878763</td>
#                         <td id="T_134bd_row7_col4" class="data row7 col4" >0.883936</td>
#             </tr>
#             <tr>
#                         <th id="T_134bd_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_134bd_row8_col0" class="data row8 col0" >['Europe', 'China']</td>
#                         <td id="T_134bd_row8_col1" class="data row8 col1" >0.285331</td>
#                         <td id="T_134bd_row8_col2" class="data row8 col2" >0.110024</td>
#                         <td id="T_134bd_row8_col3" class="data row8 col3" >0.206585</td>
#                         <td id="T_134bd_row8_col4" class="data row8 col4" >0.108030</td>

# %% [markdown]
# ### Top Industries

# %%
n = 20

df_industries = pd.DataFrame()
df_industries['region'] = regions

by_industry_group = ['industry_groups', 'industries']
by_gender_equal = ['_equal', '']

for big in by_industry_group:
    
    for bge in by_gender_equal:
        
        # initiate containers
        # top_n
        top_n_female_data = []
        top_n_not_female_data = []
        # diff
        female_diff_data = [] # female-male
        male_diff_data = [] # male-female
        
        for region in regions:
    
            df = pd.read_csv(f'../data/crunchbase-aggregated/{region}-{big}{bge}.csv')
            
            # get data
            top_n_female = list(df.sort_values(by=['#female_co'], ascending=False)[:n]['industry'])
            top_n_not_female = list(df.sort_values(by=['#not_female_co'], ascending=False)[:n]['industry'])
            female_diff = list(set(top_n_female)-set(top_n_not_female))
            male_diff = list(set(top_n_not_female)-set(top_n_female))
            
            # record data
            top_n_female_data.append(top_n_female)
            top_n_not_female_data.append(top_n_not_female)
            female_diff_data.append(female_diff)
            male_diff_data.append(male_diff)
            
        # add data to df
        if (big=='industries') and (bge==''):
            df_industries['top_n_female'] = top_n_female_data
            df_industries['top_n_not_female'] = top_n_not_female_data
            df_industries['female_diff'] = female_diff_data
            df_industries['male_diff'] = male_diff_data

        elif (big=='industries') and (bge=='_equal'):
            df_industries['top_n_female_equal'] = top_n_female_data
            df_industries['top_n_not_female_equal'] = top_n_not_female_data
            df_industries['female_diff_equal'] = female_diff_data
            df_industries['male_diff_equal'] = male_diff_data

        elif (big=='industry_groups') and (bge==''):
            df_industries['top_n_female_group'] = top_n_female_data
            df_industries['top_n_not_female_group'] = top_n_not_female_data
            df_industries['female_diff_group'] = female_diff_data
            df_industries['male_diff_group'] = male_diff_data

        elif (big=='industry_groups') and (bge=='_equal'):
            df_industries['top_n_female_group_equal'] = top_n_female_data
            df_industries['top_n_not_female_group_equal'] = top_n_not_female_data
            df_industries['female_diff_group_equal'] = female_diff_data
            df_industries['male_diff_group_equal'] = male_diff_data

# %%
df_industries_T = df_industries.set_index('region').transpose()
df_industries_T
# Out:
# region                                                                       US  \
# top_n_female_group_equal      [Software, Health Care, Science and Engineerin...
# top_n_not_female_group_equal  [Software, Information Technology, Internet Se...
# female_diff_group_equal          [Design, Community and Lifestyle, Real Estate]
# male_diff_group_equal         [Consumer Electronics, Privacy and Security, T...
# top_n_female_group            [Software, Health Care, Science and Engineerin...
# top_n_not_female_group        [Software, Information Technology, Internet Se...
# female_diff_group                [Design, Community and Lifestyle, Real Estate]
# male_diff_group               [Consumer Electronics, Privacy and Security, T...
# top_n_female_equal            [Software, Health Care, Biotechnology, SaaS, I...
# top_n_not_female_equal        [Software, Information Technology, SaaS, Healt...
# female_diff_equal             [Wellness, Medical Device, Advertising, Social...
# male_diff_equal               [Pharmaceutical, Cyber Security, FinTech, Secu...
# top_n_female                  [Software, Health Care, Biotechnology, SaaS, I...
# top_n_not_female              [Software, Health Care, Information Technology...
# female_diff                         [Social Media, Medical Device, Mobile Apps]
# male_diff                         [Internet of Things, Pharmaceutical, FinTech]
#
# region                                                                       EU  \
# top_n_female_group_equal      [Software, Internet Services, Science and Engi...
# top_n_not_female_group_equal  [Software, Internet Services, Information Tech...
# female_diff_group_equal       [Community and Lifestyle, Biotechnology, Adver...
# male_diff_group_equal         [Consumer Electronics, Transportation, Manufac...
# top_n_female_group            [Software, Internet Services, Commerce and Sho...
# top_n_not_female_group        [Software, Internet Services, Information Tech...
# female_diff_group             [Community and Lifestyle, Design, Advertising,...
# male_diff_group               [Consumer Electronics, Transportation, Profess...
# top_n_female_equal            [Software, Health Care, E-Commerce, Internet, ...
# top_n_not_female_equal        [Software, Information Technology, Internet, S...
# female_diff_equal             [Biotechnology, Fashion, Pharmaceutical, Medic...
# male_diff_equal               [Analytics, Financial Services, FinTech, Sport...
# top_n_female                  [Software, Health Care, E-Commerce, Internet, ...
# top_n_not_female              [Software, Information Technology, SaaS, Inter...
# female_diff                   [Fashion, Pharmaceutical, Medical Device, Mobi...
# male_diff                     [Analytics, Financial Services, FinTech, Enter...
#
# region                                                                   Europe  \
# top_n_female_group_equal      [Software, Internet Services, Health Care, Inf...
# top_n_not_female_group_equal  [Software, Internet Services, Science and Engi...
# female_diff_group_equal                      [Design, Advertising, Real Estate]
# male_diff_group_equal         [Consumer Electronics, Community and Lifestyle...
# top_n_female_group            [Software, Internet Services, Information Tech...
# top_n_not_female_group        [Software, Information Technology, Internet Se...
# female_diff_group                               [Design, Payments, Real Estate]
# male_diff_group               [Consumer Electronics, Transportation, Profess...
# top_n_female_equal            [Software, Health Care, E-Commerce, SaaS, Info...
# top_n_not_female_equal        [Software, Information Technology, SaaS, Finan...
# female_diff_equal             [Fashion, Medical, Advertising, Blockchain, Mo...
# male_diff_equal               [Analytics, Marketplace, Payments, FinTech, In...
# top_n_female                  [Software, Health Care, E-Commerce, SaaS, Info...
# top_n_not_female              [Software, Information Technology, Health Care...
# female_diff                   [Fashion, Blockchain, Mobile Apps, Shopping, B...
# male_diff                     [Analytics, Marketplace, Travel, FinTech, Mark...
#
# region                                                                    China
# top_n_female_group_equal      [Software, Hardware, Media and Entertainment, ...
# top_n_not_female_group_equal  [Software, Other, Media and Entertainment, Com...
# female_diff_group_equal       [Consumer Goods, Food and Beverage, Artificial...
# male_diff_group_equal         [Financial Services, Manufacturing, Content an...
# top_n_female_group            [Software, Hardware, Media and Entertainment, ...
# top_n_not_female_group        [Software, Internet Services, Information Tech...
# female_diff_group             [Consumer Goods, Food and Beverage, Artificial...
# male_diff_group               [Education, Financial Services, Manufacturing,...
# top_n_female_equal            [Artificial Intelligence, E-Commerce, Informat...
# top_n_not_female_equal        [E-Commerce, Consumer, Internet, Information T...
# female_diff_equal             [Consumer Electronics, Consumer Goods, Music, ...
# male_diff_equal               [Education, Financial Services, Manufacturing,...
# top_n_female                  [Artificial Intelligence, E-Commerce, Informat...
# top_n_not_female              [Health Care, Information Technology, Internet...
# female_diff                   [Consumer Goods, Communities, Music, Apps, Vid...
# male_diff                     [Education, Financial Services, Information Se...

# %%
# df_industries_T.to_csv(f'../data/crunchbase-aggregated/region_top_industries.csv')
