# %% [markdown]
# improved feature engineering
#
# try both datasets
# - without multilabels (**num**)
# - only adding `Industry Groups` information (**v4**)
# - also add `Headquarter Location` information, including country and state (**v5**)
# - also add `Top Investors` information, but only the most important ones (**v6**)

# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# data
import pandas as pd
import numpy as np
import ast
from numpy import mean

# visualization
import matplotlib.pyplot as plt

# chosen models
from xgboost import XGBRegressor

# data preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# feature engineering
from xgboost import plot_importance

# model training selection
from sklearn.model_selection import train_test_split
# from sklearn.model_selection import RepeatedStratifiedKFold

## model evaluation metrics
from collections import Counter
# from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse

# %% [markdown]
# ## 1. dataset without multilabels (`num`)

# %%
df = pd.read_csv('../data/feature_engineering/combined_feng_num.csv', index_col=0)
df.shape
# Out:
# (3000, 40)

# %% [markdown]
# ### split data

# %%
# get data
X = df.drop(columns='total_funding_amount_usd')
y = df['total_funding_amount_usd']

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### scale numerical features
# *also scale output feature but note data leakage, split data first then standard scale it on train data, then also use same scaler to transform test data*

# %%
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)

# %%
scaler2 = MinMaxScaler().fit(np.array(y_train).reshape(-1, 1))
y_train_scaled = scaler2.transform(np.array(y_train).reshape(-1, 1))

# %% [markdown]
# ### machine learning

# %%
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=10, seed=123)

# %%
xgb.fit(X_train_scaled, y_train_scaled)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=10, n_jobs=12, num_parallel_tree=1, random_state=123,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=123,
#              subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
pred = xgb.predict(X_test_scaled)

# %%
y_test_scaled = scaler2.transform(np.array(y_test).reshape(-1, 1))

# %%
# v2=0.01413
rmse = np.sqrt(mse(y_test_scaled, pred))
rmse
# Out:
# 0.05063493901814298

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(20,10))
plt.plot(x_ax, y_test_scaled, label="truth")
plt.plot(x_ax, pred, label="pred")
plt.title("Total Funding Amount")
plt.yscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. dataset adding `Industry Groups` info (`v4`)

# %%
df2 = pd.read_csv('../data/feature_engineering/combined_feng_v4.csv', index_col=0)
df2.shape
# Out:
# (3000, 88)

# %% [markdown]
# ### split data

# %%
# get data
X = df2.drop(columns='total_funding_amount_usd')
y = df2['total_funding_amount_usd']

# split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### scale numerical features
# *also scale output feature but note data leakage, split data first then standard scale it on train data, then also use same scaler to transform test data*

# %%
# x scaler
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)

# y scaler
scaler2 = MinMaxScaler().fit(np.array(y_train).reshape(-1, 1))
y_train_scaled = scaler2.transform(np.array(y_train).reshape(-1, 1))

# %% [markdown]
# ### machine learning

# %%
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=10, seed=123)
xgb.fit(X_train_scaled, y_train_scaled)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=10, n_jobs=12, num_parallel_tree=1, random_state=123,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=123,
#              subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
pred = xgb.predict(X_test_scaled)

# %%
y_test_scaled = scaler2.transform(np.array(y_test).reshape(-1, 1))

# %%
rmse = np.sqrt(mse(y_test_scaled, pred))
rmse
# Out:
# 0.050553980700835506

# %% [markdown]
# ## 3. dataset adding `Headquarter Location` info (`v5`)

# %%
df3 = pd.read_csv('../data/feature_engineering/combined_feng_v5.csv', index_col=0)
df3.shape
# Out:
# (3000, 345)

# %% [markdown]
# ### split data

# %%
# get data
X = df3.drop(columns='total_funding_amount_usd')
y = df3['total_funding_amount_usd']

# split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### scale numerical features
# *also scale output feature but note data leakage, split data first then standard scale it on train data, then also use same scaler to transform test data*

# %%
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)

scaler2 = MinMaxScaler().fit(np.array(y_train).reshape(-1, 1))
y_train_scaled = scaler2.transform(np.array(y_train).reshape(-1, 1))

# %% [markdown]
# ### machine learning

# %%
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=10, seed=123)
xgb.fit(X_train_scaled, y_train_scaled)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=10, n_jobs=12, num_parallel_tree=1, random_state=123,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=123,
#              subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
X_test_scaled = scaler.transform(X_test)
pred = xgb.predict(X_test_scaled)
y_test_scaled = scaler2.transform(np.array(y_test).reshape(-1, 1))

# %%
rmse = np.sqrt(mse(y_test_scaled, pred))
rmse
# Out:
# 0.050147488506450046

# %% [markdown]
# ## 4. dataset adding `Top Investors` info (`v6`)

# %%
df4 = pd.read_csv('../data/feature_engineering/combined_feng_v6.csv', index_col=0)
df4.shape
# Out:
# (3000, 423)

# %% [markdown]
# ### split data

# %%
# get data
X = df4.drop(columns='total_funding_amount_usd')
y = df4['total_funding_amount_usd']

# split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### scale numerical features
# *also scale output feature but note data leakage, split data first then standard scale it on train data, then also use same scaler to transform test data*

# %%
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)

scaler2 = MinMaxScaler().fit(np.array(y_train).reshape(-1, 1))
y_train_scaled = scaler2.transform(np.array(y_train).reshape(-1, 1))

# %% [markdown]
# ### machine learning

# %%
xgb = XGBRegressor(objective='reg:squarederror', n_estimators=10, seed=123)
xgb.fit(X_train_scaled, y_train_scaled)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=10, n_jobs=12, num_parallel_tree=1, random_state=123,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=123,
#              subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
X_test_scaled = scaler.transform(X_test)
pred = xgb.predict(X_test_scaled)
y_test_scaled = scaler2.transform(np.array(y_test).reshape(-1, 1))

# %%
rmse = np.sqrt(mse(y_test_scaled, pred))
rmse
# Out:
# 0.05031101783671791

# %% [markdown]
# <span style="color:red">
# Compared to the rmse before (`0.014`), the current rmse, `0.0506` for numerical, `0.0505` for adding industry groups, `0.0501` for adding headquarters location, and `0.0503` after adding investors info, are all not good enough!!
