# %% [markdown]
# # classification with xgboost
# model v4
# - preliminary model (no hyperparameter tuning)
# - data with all 1352 important features based on pca and threshold
# - imbalanced classification dealt with using weighted xgboost (`scale_pos_weight`)
# - using data with 2197 rows
# - only taking weight 40 for shap experimentation

# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# data
import pandas as pd
import numpy as np
import ast
from numpy import mean

# visualization
import matplotlib.pyplot as plt

# chosen models
from xgboost import XGBClassifier

# feature engineering
from xgboost import plot_importance

# model training selection
from sklearn.model_selection import train_test_split
# from sklearn.model_selection import RepeatedStratifiedKFold

## model evaluation metrics
from collections import Counter
# from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import cohen_kappa_score

# important cols
import shap

# print the JS visualization code to the notebook
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
df = pd.read_csv('../data/feature_engineering/combined_feng_dropna.csv', index_col=0)
df.shape
# Out:
# (2197, 7353)

# %%
df.head(3)
# Out:
#                                Number of Founders  Number of Funding Rounds  \
# Organization Name
# CMC                                             1                         1
# Ping An Healthcare Management                   1                         1
# LeSee                                           1                         1
#
#                                Trend Score (7 Days)  Trend Score (30 Days)  \
# Organization Name
# CMC                                            -0.4                   -0.8
# Ping An Healthcare Management                  -0.1                   -0.2
# LeSee                                          -0.4                    0.0
#
#                                Trend Score (90 Days)  Early Stage Venture  \
# Organization Name
# CMC                                             -1.2                  1.0
# Ping An Healthcare Management                   -0.4                  1.0
# LeSee                                           -0.5                  1.0
#
#                                M&A  Seed  Made Acquisitions  \
# Organization Name
# CMC                            0.0   0.0                0.0
# Ping An Healthcare Management  0.0   0.0                0.0
# LeSee                          0.0   0.0                0.0
#
#                                Made Acquisitions; Was Acquired  ...  \
# Organization Name                                               ...
# CMC                                                        0.0  ...
# Ping An Healthcare Management                              0.0  ...
# LeSee                                                      0.0  ...
#
#                                last_funding_amount   cvr  \
# Organization Name
# CMC                                    10000000000  0.16
# Ping An Healthcare Management           1150000000  1.00
# LeSee                                   1080000000  1.00
#
#                                last_funding_amount_usd  \
# Organization Name
# CMC                                       1.600000e+09
# Ping An Healthcare Management             1.150000e+09
# LeSee                                     1.080000e+09
#
#                                last_equity_funding_amount  \
# Organization Name
# CMC                                           10000000000
# Ping An Healthcare Management                  1150000000
# LeSee                                          1080000000
#
#                                last_equity_funding_amount_usd  \
# Organization Name
# CMC                                              1.600000e+09
# Ping An Healthcare Management                    1.150000e+09
# LeSee                                            1.080000e+09
#
#                                total_equity_funding_amount  \
# Organization Name
# CMC                                            10000000000
# Ping An Healthcare Management                   1150000000
# LeSee                                           1080000000
#
#                                total_equity_funding_amount_usd  \
# Organization Name
# CMC                                               1.600000e+09
# Ping An Healthcare Management                     1.150000e+09
# LeSee                                             1.080000e+09
#
#                                total_funding_amount  total_funding_amount_usd  \
# Organization Name
# CMC                                     10000000000              1.600000e+09
# Ping An Healthcare Management            1150000000              1.150000e+09
# LeSee                                    1080000000              1.080000e+09
#
#                                female_led
# Organization Name
# CMC                                     0
# Ping An Healthcare Management           0
# LeSee                                   0
#
# [3 rows x 7353 columns]

# %% [markdown]
# ### get all top features based on pca

# %%
with open('high_var_org_col_index.txt', 'r') as reader:
    high_var_org_col_index = reader.read()

# %%
high_var_org_col_index = ast.literal_eval(high_var_org_col_index)

# %%
df1352 = df[df.columns[high_var_org_col_index]]

# %% [markdown]
# ### split data

# %%
# get data
X = df1352
y = df['female_led']

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## model evaluation

# %%
def metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred) #perfect=1
    precision = precision_score(y_true, y_pred) #perfect=1
    recall = recall_score(y_true, y_pred) #perfect=1
    f1 = f1_score(y_true, y_pred) #perfect=1
#     roc_auc = roc_auc_score(y, clf.decision_function(X)) #perfect=1
#     log = log_loss(y_true, y_pred) #perfect=0
    mcc = matthews_corrcoef(y_true, y_pred) #perfect=1
    kappa = cohen_kappa_score(y_true, y_pred) #perfect=1
    
#     print(f'accuracy={accuracy},\
#             precision={precision}, recall={recall}, \
#             f1={f1}, mcc={mcc}, kappa={kappa}')

    return [accuracy, precision, recall, f1, mcc, kappa]

# %%
def evaluate(model, X_train=X_train, X_test=X_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return metrics(y_test, y_pred)

# %% [markdown]
# ## machine learning
#
# Gradients are used as the basis for fitting subsequent trees added to boost or correct errors made by the existing state of the ensemble of decision trees.
#
# The `scale_pos_weight` value is used to scale the gradient for the positive class. The scale_pos_weight can be used to train a class-weighted or cost-sensitive version of XGBoost for imbalanced classification.
#
# A sensible default value to set for the scale_pos_weight hyperparameter is the inverse of the class distribution. For example, for a dataset with a 1 to 100 ratio for examples in the minority to majority classes, the scale_pos_weight can be set to 100. This will give classification errors made by the model on the minority class (positive class) 100 times more impact, and in turn, 100 times more correction than errors made on the majority class.

# %%
y.value_counts()
# Out:
# 0    2055
# 1     142
# Name: female_led, dtype: int64

# %%
2858/142 #class imbalance proportion
# Out:
# 20.12676056338028

# %%
xgb = XGBClassifier(scale_pos_weight=40)
metrics_xgb = evaluate(xgb)
metrics_xgb
# Out:
# [15:58:11] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0.9256198347107438,
#  0.22727272727272727,
#  0.11904761904761904,
#  0.15624999999999997,
#  0.1282854571699507,
#  0.12130177514792895]

# %%
important_features_dict = xgb.get_booster().get_score(importance_type='weight')
important_cols = list(important_features_dict.keys())

# %%
len(important_cols)
# Out:
# 77

# %%
plt.rcParams["figure.figsize"] = (20, 15)
plot_importance(xgb, max_num_features=50)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## explain predictions with shap

# %%
explainer = shap.TreeExplainer(xgb)
shap_values = explainer.shap_values(X)

# %%
# visualize a single prediction
shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])
# Out:
# <div id='iR51UTOY1URW7LRX4R3FK'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 1.3245725631713867, "outValue": -4.290038585662842, "link": "identity", "featureNames": ["Qianfan Capital", "Shanghai Zuyuan Investment Management", "Orient Shiqi Fund", "Zhongjun Capital", "Perfect Investment Group", "Zhixin Capital", "Elaia", "Video Games", "Huizun Capital Management Co.", "Trend Score (7 Days)", "HY Capital", "Trend Score (90 Days)", "Consumer", "Huangshan Panjie Fund", " Inventures SA", "RRJ Capital", " Sex Industry", "Holden", "Oriental Fortune Capital", "Hyfinity Investments", "Chinese Entrepreneur Association (CEA)", "Private Social Networking", "Shandong Minghai Group Co", "Shenzhen Zhicheng Haiwei Asset Management", "Zheshang Industrial Integration Asset Management", "Picus Capital", "Shasta Ventures", "Fosun Pharma", "Russian Direct Investment Fund", "Chenghe Capital", "InsurTech", "Omar Ayesh", "GF Securities", "Energy", "Trustbridge Partners", "Motive Partners", "SymphonyAI", " Highlight Capital", "Ares Management", "Zhejiang Pudu Technology", " STEM Education", " 10Fund", "Br\u00fcgg", " Nutraceutical", "Qipu Capital", "Jinhang Industry Investment", " Apps", "StartX (Stanford-StartX Fund)", "cvr", "Shanghai Yuanshi Equity Investment Fund Management Co.", "Kangmei Pharmaceutical", "Juhe Capital", " Afore Capital", " Handling Thin Or Filamentary Material", " Storing", " Leonis Investissement", "Conveying", " Packing", " Toyota Ventures", "Logistics", "Smallville Capital", "Western US", "rpcx", "Los Gatos", " Spring Weight And Miscellaneous Motors", " Producing Mechanical Power", " Or A Reactive Propulsive Thrust", "Wind", " Not Otherwise Provided For", " Qianhai Wutong Mergers and Acquisitions Funds", "Yuanlong Investment", " Banking", "Perceptive Advisors", " Zhuhai Huajin Asset", " Robert Facchina", "Stripes", " Corely", " Security", "Family", "Kaitai Capital", "Real Time", "Amr Zedan", "Yueyin Venture Capital", " Gyor", "Gyor", "Rubber and plastic goods", " packing", " stopping and insulating materials", " Plastics and Rubber Manufacturing", " Idaho", "Idaho Falls", "Qianhai Zhongwei Capital", "Internet of Things", "PaaS", "Cherubic Ventures", "Tisiwi Ventures", " Hangzhou Everfine Photo-E-Info", "Zhonglu Capital", "Finch Capital", "Qualcomm Ventures", "Angel Investment", "Harbin", " Furniture", " Manufacturing", "Sagemoore Capital", "Holbrook", "Lingdu Capital", "Hybio Pharmaceutical", "Berliner Volksbank Ventures", " Sheffield", "Parkinson's UK", "Sheffield", "Rising Sun", " Home Inn", "SBI Group", "Edge Ventures", "Delivery Service", "Conviction Investment Partners", " Joy Capital", " Halogen Ventures", "BDMI", " Vine St. Ventures", " BIP Capital", "Bowling Green", " Kentucky", " Archer Gray", "Li Xiang", "Zongton Capital", "CBC Capital", " The Hina Group", "active_tech_count", "Charter Schools", " Online Auctions", " Fudewu Sheng", " Ailifang Touzi", " Haerbin Chuangxin Tou", " Hatou Jituan", "Oriza Seed Capital (Oriza Yuandian)", "Munich", "Medical", "Sofinnova Partners", " Talent Capital", " JCBank", " Lezhile Shuma Keji", " Goldbridge Capital", "Taiyuan", "Tianjin Renai Capital", "Invus", "Twelve Skeps", "AlbionVC", "China Galaxy Securities", " Heyue Capital", " Happy East Capital", "Sky9 Capital", "Toutoushidao Capital", " Balzers", "Balzers", " Dieter Schmid", " Marco Schmid", "Ueli Breitschmid", " UMD Invest", "Finance", " Primer Capital", " Techaser", " NIC Fund", " Magic Johnson Enterprises", " MedTech Innovator", " CRM", " Video Streaming", "Manufacturing", "Deerfield", "Iris Capital", "Organic Macromolecular Compounds", " Their Preparation Or Chemical Working-Up", "Siena", "Espoo", "YC Partners", "Domain Associates", "last_funding_month", " scouring and abrasive preparations", "Bleaching", " cosmetics", " cleaning", " polishing", "China Capital Financial Service Chamber of Commerce", " Sofinnova Investments", "Manchester", " Manchester", "Woodside Incubator", "Ravichandra Reddy Vakati", "T ...

# %%
# # visualize many predictions
# shap.force_plot(explainer.expected_value, 
#                 shap_values[:1000,:], X.iloc[:1000,:])

# %% [markdown]
# ### bar chart of mean importance

# %%
shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### shap summary plot

# %%
shap.summary_plot(shap_values, X)

# %% [markdown]
# ### shap dependence plots

# %%
important_cols = ['Number of Founders', 'total_funding_amount_usd', 'cb_rank_(company)', 'active_tech_count', 'Trend Score (90 Days)', 'last_funding_month', 'European Union (EU)', 'visit_duration', 'Number of Funding Rounds', 'estimated_revenue_range', 'number_of_employees', 'E-Commerce']

# %%
for name in important_cols:
    shap.dependence_plot(name, shap_values, X)
